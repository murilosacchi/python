# %% [markdown]
# # **TTI109 - Estatística**
# ## **Análise Descritiva/Exploratória de Dados**
# ## Atividade 1

# %% [markdown]
# # **INSTRUÇÕES**
# - Preencha a célula de identificação de forma adequada;
# - Leia as informações contidas na seção `Definições` e `Introdução à Análise Exploratória com Pandas`;
# - Para envio no Open LMS: envie o arquivo `*.ypynb` e `*.PDF` com as soluções.
# - **ENVIO: 08.10.2023**

# %%
#@title Identificação
Nome = "Murilo Sucupira Sacchi" #@param {type:"string"}
RA = "23.10260-8" #@param {type:"string"}

Nome = "Seu nome (sem acentos)" #@param {type:"string"}
RA = "Seu RA (no formato XX.XXXXX-X)" #@param {type:"string"}

# %% [markdown]
# # Definições

# %% [markdown]
# Análise exploratória de dados (AED) ou *EDA - Exploratory Data Analysis* - é uma abordagem de análise de conjuntos de dados, geralmente com o auxílio de técnicas de visualização de dados, para entender suas principais características. A ideia é explorar ao máximo as informações disponíveis antes de formular hipóteses, criar modelos ou fazer inferências. A AED é fundamental na ciência de dados e na análise estatística.
#
# A AED pode incluir o seguinte:
#
# * **Resumo estatístico:** O primeiro passo na AED é geralmente obter um resumo estatístico dos dados. Isso inclui medidas de centralidade como média, mediana e moda, e medidas de dispersão como variação e desvio padrão.
#
# * **Análise de formas de distribuição:** Este é um passo importante para entender como os dados estão distribuídos. Isso pode incluir a construção de histogramas, diagramas de caixa (boxplots) e gráficos de densidade.
#
# * **Análise de relação entre variáveis:** Se houver múltiplas variáveis no conjunto de dados, pode ser útil entender a relação entre elas. Isso pode incluir a construção de gráficos de dispersão e calcular coeficientes de correlação.
#
# * **Identificação de valores atípicos:** Valores atípicos podem ter um grande efeito na análise, portanto, é importante identificá-los durante a fase de AED.
#
# * **Testes de hipóteses:** Embora a AED seja principalmente sobre a exploração sem qualquer hipótese prévia, às vezes os insights obtidos durante a AED podem levar a testes de hipóteses para confirmar se uma observação é estatisticamente significativa.
#
# A análise exploratória de dados é um componente essencial de qualquer análise de dados e ajuda a entender a estrutura subjacente dos dados, identificar outliers ou anomalias, e encontrar padrões interessantes nos dados.

# %% [markdown]
# # Introdução à Análise Exploratória com Pandas

# %% [markdown]
# O Pandas é uma das principais bibliotecas para exploração e entendimento dos dados.
#
# A seguir, estão os principais e mais utilizados recursos:
#
# <br>
#
# 1. **Importação dos Dados**
#
# Primeiro, importe o conjunto de dados usando pandas. O pandas é uma biblioteca Python que fornece estruturas de dados e ferramentas de análise de dados de alto desempenho.
#
# `import pandas as pd`
#
# `df = pd.read_csv('covid_dataset.csv')  # Substitua com o nome correto do seu arquivo`
#
# <br>
#
# 2. **Exploração Inicial dos Dados**
#
# Confira as primeiras e últimas linhas do dataframe para ter uma ideia inicial dos dados.
#
# `df.head()  # Visualiza as primeiras linhas do dataframe`
#
# `df.tail()  # Visualiza as últimas linhas do dataframe`
#
#
# Verifique a estrutura do dataframe:
#
# `df.info()`
#
#
# E faça um resumo estatístico dos dados numéricos:
#
# `df.describe()`
#
# Faça um contagem dos valores ausentes:
#
# `df.isna.sum()`
#
# <br>
#
# 3. **Limpeza de Dados**
#
# Limpe os dados, se necessário. Isso pode incluir o tratamento de valores nulos, remoção de colunas desnecessárias, e assim por diante.
#
# `df = df.dropna()  # Remove linhas com valores nulos
# df = df.drop(columns=['column_to_drop'])  # Remove colunas desnecessárias`
#
# <br>
#
# 4. **Análise dos Dados**
#
# Agora, você pode começar a analisar os dados. A natureza exata desta análise dependerá do seu conjunto de dados, mas algumas coisas que você pode fazer incluem:
#
# * Visualizar a distribuição de casos confirmados e mortes usando histogramas e boxplots.
# * Comparar a taxa de casos confirmados e mortes entre diferentes países ou estados.
# Observar a tendência de casos e mortes ao longo do tempo.
#
# Por exemplo, você pode querer visualizar a distribuição de casos confirmados usando um histograma:
#
# `import matplotlib.pyplot as plt`
#
# `plt.hist(df['confirmed_cases'], bins=30)`
#
# `plt.title('Distribuição de Casos Confirmados')`
#
# `plt.xlabel('Casos Confirmados')`
#
# `plt.ylabel('Frequência')`
#
# `plt.show()`
#
# <br>
#
# 5. **Análise de Correlação**
#
# Examine a correlação entre diferentes variáveis. Por exemplo, você pode estar interessado na correlação entre casos confirmados e mortes.
#
# `correlation = df['confirmed_cases'].corr(df['deaths'])`
#
# <br>
#
# Com esse resultado, pode-se plotar um gráfico chamado heatmap:
#
# `df = pd.DataFrame(dados)`
#
# `# Calcule a matriz de correlação`
#
# `corr_matrix = df.corr()`
#
# `# Crie o gráfico de heatmap usando o seaborn`
#
# `sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')`
#
# `# Exiba o gráfico`
#
# `plt.show()`
#
# <br>
#
# 6. **Identificação de Outliers**
#
# Valores atípicos podem afetar a análise de dados, então é uma boa ideia identificar e entender quaisquer outliers potenciais em seu conjunto de dados. Você pode fazer isso graficamente usando boxplots, ou analiticamente usando métodos estatísticos.
#
# <br>
#
# 7. **Testes de Hipóteses**
#
# Dependendo do que você descobrir durante a análise exploratória, você pode querer realizar testes de hipóteses para determinar se os padrões que você observa são estatisticamente significativos.
#
# Lembre-se de que esses são apenas alguns passos básicos e a análise específica dependerá muito do conjunto de dados que você está usando e das questões que você está tentando responder.
#
# <br>
#
# 8. **Seleção de colunas**
#
# Você pode selecionar colunas em um DataFrame usando a sintaxe de colchetes ou usando o operador ponto.
#
# `df['nome_da_coluna']`
# `df.nome_da_coluna`
#
# <br>
#
# 9. **Seleção de linhas**
#
# Você pode selecionar linhas em um DataFrame usando a função loc para rótulos de linha ou iloc para posições de linha:
#
# `df.loc[rotulo_da_linha]`
# `df.iloc[posicao_da_linha]`
#
# <br>
#
# 10. **Filtragem**
#
# Você pode filtrar linhas em um DataFrame com base em uma condição:
#
# `df[df['nome_da_coluna'] > valor]`
#
# <br>
#
# 11. **Agrupamento**
#
# A função `groupby()` é usada para agrupar o `DataFrame` com base em uma ou mais colunas, e você pode aplicar funções agregadas como `mean()`, `
# min()`, `max()`, `sum()`, etc. ao grupo resultante:
#
# `df.groupby('nome_da_coluna').mean()`
#
# <br>
#
# 12. **Manipulação de valores ausentes**
#
# As funções `isnull()` e `notnull()` são usadas para detectar valores ausentes, e as funções `dropna()` e `fillna()` são usadas para tratar valores ausentes:
#
# `df.isnull()`
#
# `df.dropna()`
#
# `df.fillna(valor)`
#
# <br>
#
# 13. **Criação de novas colunas**
#
# Você pode criar novas colunas a partir de colunas existentes.
#
# `df['nova_coluna'] = df['coluna1'] + df['coluna2']`
#
# <br>
#
# 14. **Aplicando funções a colunas**
#
# Use o método `.apply()` para aplicar uma função a cada elemento de uma coluna.
#
# `# Aplica a função np.sqrt (raiz quadrada do NumPy) à coluna 'A'`
#
# `df['A'] = df['A'].apply(np.sqrt)`
#
# <br>
#
# 15. **Ordenando os dados**
#
# Use o método `.sort_values()` para ordenar o `DataFrame`.
#
# `# Ordena o DataFrame com base na coluna 'A'`
#
# `df = df.sort_values('A')`
#
# <br>
#
# 16. **Juntando DataFrames**
#
# Use os métodos `.merge()` e `.concat()` para juntar dois ou mais `DataFrames`.
#
# `# Junta dois DataFrames ao longo das colunas`
#
# `df = pd.concat([df1, df2], axis=1)`
#
# `# Merge de dois DataFrames com base em uma coluna chave`
#
# `df = pd.merge(df1, df2, on='key_column')`
#
# <br>
#
# Para saber mais:
# * https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
#
#
# <br>
#
# 17. **Alterando o índice**
#
# Use o método `.set_index()` para alterar o índice do `DataFrame`.
#
# `# Define a coluna 'A' como índice`
#
# `df = df.set_index('A')`
#
# <br>
#
# 18. **Resetando o índice**
#
# Use o método `.reset_index()` para resetar o índice do `DataFrame`.
#
# `# Reset o índice`
# `df = df.reset_index()`
#
# <br>
#
# 19. **Renomeando colunas**
#
# Use o método `.rename()` para renomear colunas.
#
# `# Renomeia a coluna 'A' para 'new_A'`
#
# `df = df.rename(columns={'A': 'new_A'})`
#
# <br>
#
# 20. **Selecionando valores únicos**
#
# Use o método `.unique()` para obter valores únicos de uma coluna.
#
# `# Retorna valores únicos da coluna 'A'`
# `unique_values = df['A'].unique()``
#
# <br>
#
# 21. **Contando valores únicos**
#
# Use o método `.value_counts()` para contar a ocorrência de valores únicos em uma coluna.
#
# `# Conta ocorrências de valores únicos na coluna 'A'`
#
# `value_counts = df['A'].value_counts()`
#
# <br>
#
# 22. **Conversão de tipos de dados**
#
# Use o método `.astype()` para converter o tipo de dados de uma coluna.
#
# `# Converte a coluna 'A' para int`
#
# `df['A'] = df['A'].astype(int)`
#
# <br>
#
# As funções `pd.to_numeric()` e `pd.to_datetime()` são funções da biblioteca pandas em Python para converter os dados de uma coluna específica em tipos numéricos e de data/hora, respectivamente. Aqui está uma explicação de cada uma delas:
#
# 1. `pd.to_numeric(df[a]):`
#
# * `df[a]`: É a coluna do DataFrame df que você deseja converter para um tipo numérico.
# * `pd.to_numeric()`: É uma função que converte os valores da coluna em números. Se houver algum valor inválido ou não numérico na coluna, o pandas converterá esse valor para `NaN`.
#
# * Sintaxe correta: `df[a] = pd.to_numeric(df[a])`
#
# 2. `pd.to_datetime(df[a])`:
#
# * `df[a]`: É a coluna do DataFrame df que você deseja converter para o tipo de data/hora.
# * `pd.to_datetime()`: É uma função que converte os valores da coluna em objetos de data/hora do pandas.
# * Sintaxe correta: `df[a] = pd.to_datetime(df[a])`

# %% [markdown]
# # Problema
#
# <br>
#
# A pandemia de COVID-19, também conhecida como pandemia de coronavírus, foi causada pelo coronavírus da síndrome respiratória aguda grave 2 (SARS-CoV-2). O vírus foi identificado pela primeira vez a partir de um surto em Wuhan, China, em dezembro de 2019.
#
# As tentativas de contê-lo falharam, permitindo que o vírus se espalhasse para outras áreas da China e, posteriormente, para todo o mundo. Em 30 de janeiro de 2020, a Organização Mundial da Saúde (OMS) classificou o surto como Emergência de Saúde Pública de Âmbito Internacional (PHEIC) e, em 11 de março de 2020, como pandemia. Até 22 de maio de 2023, 676.609.955 casos foram confirmados em 228 países e territórios, com 6.881.955 mortes atribuídas à doença, tornando-se uma das mais mortais da história. A OMS declarou o fim da PHEIC causada pela pandemia no dia 5 de maio de 2023.
#
# Em 17 de janeiro de 2021, iniciou-se a [vacinação contra a COVID-19 no Brasil.](https://portal.fiocruz.br/noticia/vacinacao-contra-covid-19-no-brasil-completa-um-ano
# )
#
# Assim, utilizando os dados sobre vacinação e COVID disponíveis no portal [Coronovavírus Brasil](https://covid.saude.gov.br/), responda: a vacinação foi ou nao essencial para o controle da pandemia no país? Justifique sua posição com uma análise exploratória de dados.

# %% [markdown]
# # Setup Python

# %%
# Import das Bibliotecas
import pandas as pd  # Importa a biblioteca Pandas para manipulação de dados tabulares
import numpy as np  # Importa a biblioteca NumPy para operações numéricas eficientes
import matplotlib.pyplot as plt  # Importa a biblioteca Matplotlib para visualização de dados
import matplotlib.dates as mdates
import seaborn as sns  # Importa a biblioteca Seaborn para visualização estatística de dados
import math  # Importa o módulo math para funções matemáticas

# %%
# Biblioteca para trabalhar com arquivos em MS Excel
# !pip install openpyxl

# %%
# Define uma semente randômica
np.random.seed(42)  # Define a semente aleatória para reproduzibilidade dos resultados

# %% [markdown]
# # Análise Exploratória

# %% [markdown]
# ## Importação dos dados e tratamento de dados

# %%
# importando os datasets para análise

# !gdown 1TLQINbxl-CKBaK5TJ4D7HGNpIlnVOYJg
# !gdown 1SUttXcB9eSwIw_RIOpyFTEms9I8_i7Ht
# !gdown 1OR8cYD-_xwZyf3zX5rgGV8rHXXCeX2cX
# !gdown 1kXXeNYhVI59NOac11KBeQN_ItrEsPioa
# !gdown 1jypd-AqPlNennEd3As09gQUI2KMRLEL5
# !gdown 1wqPFIGuUYr4xfa1EtXqRbwCZzaAsEjD3
# !gdown 1fxTkvmZsxBCYPc2UtG8Uk0f9thh1SLFm
# !gdown 1yTOC50chr4TzZZItvrargIbXZdQOsQG5
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1TLQINbxl-CKBaK5TJ4D7HGNpIlnVOYJg
# To: /content/HIST_PAINEL_COVIDBR_2020_Parte1_26mai2023.csv
# 100% 62.5M/62.5M [00:01<00:00, 54.1MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1SUttXcB9eSwIw_RIOpyFTEms9I8_i7Ht
# To: /content/HIST_PAINEL_COVIDBR_2020_Parte2_26mai2023.csv
# 100% 76.5M/76.5M [00:01<00:00, 66.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1OR8cYD-_xwZyf3zX5rgGV8rHXXCeX2cX
# To: /content/HIST_PAINEL_COVIDBR_2021_Parte1_26mai2023.csv
# 100% 91.1M/91.1M [00:00<00:00, 108MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1kXXeNYhVI59NOac11KBeQN_ItrEsPioa
# To: /content/HIST_PAINEL_COVIDBR_2021_Parte2_26mai2023.csv
# 100% 93.4M/93.4M [00:01<00:00, 57.8MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1jypd-AqPlNennEd3As09gQUI2KMRLEL5
# To: /content/HIST_PAINEL_COVIDBR_2022_Parte1_26mai2023.csv
# 100% 91.8M/91.8M [00:01<00:00, 53.2MB/s]
# Downloading...
# ...

# %%
# criando os dataframes

df_2020_1 = pd.read_csv('HIST_PAINEL_COVIDBR_2020_Parte1_26mai2023.csv', sep=";")
df_2020_2 = pd.read_csv('HIST_PAINEL_COVIDBR_2020_Parte2_26mai2023.csv', sep=";")
df_2021_1 = pd.read_csv('HIST_PAINEL_COVIDBR_2021_Parte1_26mai2023.csv', sep=";")
df_2021_2 = pd.read_csv('HIST_PAINEL_COVIDBR_2021_Parte2_26mai2023.csv', sep=";")
df_2022_1 = pd.read_csv('HIST_PAINEL_COVIDBR_2022_Parte1_26mai2023.csv', sep=";")
df_2022_2 = pd.read_csv('HIST_PAINEL_COVIDBR_2022_Parte2_26mai2023.csv', sep=";")
df_2023_1 = pd.read_csv('HIST_PAINEL_COVIDBR_2023_Parte1_26mai2023.csv', sep=";")
df_vacinados = pd.read_excel('2e6c36f7-a0ca-4a38-b25d-6703da0e8ea6.xlsx')

# %% [markdown]
# ## EX01
# Escolha e visualize um dos datasets importados.

# %%
# visualizando um dataframe

print(df_2020_1)
# Out:
#               regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 0             Brasil    NaN       NaN     76       NaN             NaN
# 1             Brasil    NaN       NaN     76       NaN             NaN
# 2             Brasil    NaN       NaN     76       NaN             NaN
# 3             Brasil    NaN       NaN     76       NaN             NaN
# 4             Brasil    NaN       NaN     76       NaN             NaN
# ...              ...    ...       ...    ...       ...             ...
# 714476  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 714477  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 714478  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 714479  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 714480  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#          nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...

# %% [markdown]
# ## EX02:
# Obtenha, com um único comando, os nomes das colunas, quantidade de registros não-nulos e tipo das colunas do DataFrame que foi visualizado acima. Lembre-se que você está usando o Pandas.

# %%
df_2020_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714481 entries, 0 to 714480
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   regiao                  714481 non-null  object
#  1   estado                  714323 non-null  object
#  2   municipio               707390 non-null  object
#  3   coduf                   714481 non-null  int64
#  4   codmun                  710057 non-null  float64
#  5   codRegiaoSaude          707390 non-null  float64
#  6   nomeRegiaoSaude         707390 non-null  object
#  7   data                    714481 non-null  object
#  8   semanaEpi               714481 non-null  int64
#  9   populacaoTCU2019        711814 non-null  float64
#  10  casosAcumulado          714481 non-null  int64
#  11  casosNovos              714481 non-null  int64
#  12  obitosAcumulado         714481 non-null  int64
#  13  obitosNovos             714481 non-null  int64
# ...

# %% [markdown]
# ## EX03:
# Faça uma contagem por `região` deste dataset.

# %%
df_2020_1['regiao'].count()
# Out:
# 714481

# %% [markdown]
# ## EX04:
# Faça uma contagem por `data` deste dataset.

# %%
df_2020_1['data'].count()
# Out:
# 714481

# %% [markdown]
# ## EX05:
# Faça a contagem dos valores ausentes desse dataset.

# %%
df_2020_1.isnull().sum()
# Out:
# regiao                         0
# estado                       158
# municipio                   7091
# coduf                          0
# codmun                      4424
# codRegiaoSaude              7091
# nomeRegiaoSaude             7091
# data                           0
# semanaEpi                      0
# populacaoTCU2019            2667
# casosAcumulado                 0
# casosNovos                     0
# obitosAcumulado                0
# obitosNovos                    0
# Recuperadosnovos          714323
# emAcompanhamentoNovos     714323
# interior/metropolitana      7091
# dtype: int64

# %% [markdown]
# **Conclusão:**
# <br>
# Portanto, há indícios de que no mesmo dataset há informações sobre o total acumulados no Br e também por Estado e Região!

# %% [markdown]
# ## EX06:
# Faça a consolidação dos datasets de 2020, ou seja, transforme de dois para um dataset!

# %%
# consolidando dataframes

# 2020
df_2020 = pd.concat([df_2020_1, df_2020_2])

# %% [markdown]
# ## EX07:
# Obtenha, com um único comando, os nomes das colunas, quantidade de registros não-nulos e tipo das colunas do dataset gerado para 2020. Lembre-se que você está usando o Pandas.

# %%
df_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1574188 entries, 0 to 859706
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   regiao                  1574188 non-null  object
#  1   estado                  1573877 non-null  object
#  2   municipio               1559600 non-null  object
#  3   coduf                   1574188 non-null  int64
#  4   codmun                  1565480 non-null  float64
#  5   codRegiaoSaude          1559600 non-null  float64
#  6   nomeRegiaoSaude         1559600 non-null  object
#  7   data                    1574188 non-null  object
#  8   semanaEpi               1574188 non-null  int64
#  9   populacaoTCU2019        1568308 non-null  float64
#  10  casosAcumulado          1574188 non-null  int64
#  11  casosNovos              1574188 non-null  int64
#  12  obitosAcumulado         1574188 non-null  int64
# ...

# %% [markdown]
# ## EX08:
# Faça uma contagem de por `região` para o ano de 2020.

# %%
df_2020_regiao = df_2020['regiao'].value_counts()

# %%
print(df_2020_regiao)
# Out:
# Nordeste        507639
# Sudeste         469404
# Sul             335253
# Centro-Oeste    132564
# Norte           129017
# Brasil             311
# Name: regiao, dtype: int64

# %% [markdown]
# ## EX09:
# Consolide em um dataset, os 4 anos de informações disponíveis. Dica: chame esse DataFrame de `df_total`. Esse DataFrame deverá conter os dados de 2020 à 2023.

# %%
# consolidando um dataframe com todas as infos dos 4 anos de análise

df_total = pd.concat([df_2020, df_2021_1, df_2021_2, df_2022_1, df_2022_2, df_2023_1])

# %% [markdown]
# ## EX10:
# Obtenha, com um único comando, os nomes das colunas, quantidade de registros não-nulos e tipo das colunas do DataFrame que foi visualizado acima. Lembre-se que você está usando o Pandas.

# %%
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6496432 entries, 0 to 820373
# Data columns (total 17 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   regiao                  object
#  1   estado                  object
#  2   municipio               object
#  3   coduf                   int64
#  4   codmun                  float64
#  5   codRegiaoSaude          float64
#  6   nomeRegiaoSaude         object
#  7   data                    object
#  8   semanaEpi               int64
#  9   populacaoTCU2019        float64
#  10  casosAcumulado          float64
#  11  casosNovos              int64
#  12  obitosAcumulado         int64
#  13  obitosNovos             int64
#  14  Recuperadosnovos        float64
#  15  emAcompanhamentoNovos   float64
#  16  interior/metropolitana  float64
# dtypes: float64(7), int64(5), object(5)
# memory usage: 892.1+ MB

# %% [markdown]
# ## EX11:
# Qual o total de linhas desse `df_total`?

# %%
linhas = df_total.shape[0]

# %%
print(f'O total de linhas do df_total é {linhas}')
# Out:
# O total de linhas do df_total é 6496432

# %% [markdown]
# ## Análise descritiva

# %% [markdown]
# ## EX12:
# Utilizando a método adequado do Pandas, obtenha a análise descritiva básica do `df_total`. Dica: o resultado deverá conter a contagem de linhas, média, desvio padrão, quartis e demais informações informações.

# %%
df_total.describe()
# Out:
#               coduf        codmun  codRegiaoSaude     semanaEpi  \
# count  6.496432e+06  6.463196e+06    6.438920e+06  6.496432e+06
# mean   3.236017e+01  3.252580e+05    3.240312e+04  2.620385e+01
# std    9.874232e+00  9.853503e+04    9.836342e+03  1.487999e+01
# min    1.100000e+01  1.100000e+05    1.100100e+04  1.000000e+00
# 25%    2.500000e+01  2.512000e+05    2.501000e+04  1.400000e+01
# 50%    3.100000e+01  3.146100e+05    3.105900e+04  2.500000e+01
# 75%    4.100000e+01  4.119150e+05    4.101500e+04  3.900000e+01
# max    7.600000e+01  5.300100e+05    5.300100e+04  5.300000e+01
#
#        populacaoTCU2019  casosAcumulado    casosNovos  obitosAcumulado  \
# count      6.472156e+06    6.496432e+06  6.496432e+06     6.496432e+06
# mean       1.146170e+05    1.112695e+04  1.735369e+01     2.506071e+02
# std        2.973966e+06    3.391122e+05  7.132076e+02     7.459765e+03
# min        7.810000e+02    0.000000e+00 -2.955860e+05     0.000000e+00
# ...

# %% [markdown]
# Analisaremos:
#
# * Óbitos: novos/acumulados
# * Casos: novos/acumulados

# %% [markdown]
# ## EX13:
# Faça um filtro no `df_total` criando um outro DataFrame contendo:
# - data;
# - região;
# - casosAcumulado;
# - casosNovos;
# - obitosAcumulado;
# - obitosNovos.
#
# Dica: chame esse novo DataFrame de `df_total_ft`

# %%
# criando um filtro no df_total para analise grafica

df_total_ft = df_total[['data', 'regiao', 'casosAcumulado', 'casosNovos', 'obitosAcumulado', 'obitosNovos']]

# %%
print(df_total_ft)
# Out:
#               data        regiao  casosAcumulado  casosNovos  obitosAcumulado  \
# 0       2020-02-25        Brasil             0.0           0                0
# 1       2020-02-26        Brasil             1.0           1                0
# 2       2020-02-27        Brasil             1.0           0                0
# 3       2020-02-28        Brasil             1.0           0                0
# 4       2020-02-29        Brasil             2.0           1                0
# ...            ...           ...             ...         ...              ...
# 820369  2023-05-22  Centro-Oeste        907556.0           0            11859
# 820370  2023-05-23  Centro-Oeste        907556.0           0            11859
# 820371  2023-05-24  Centro-Oeste        907556.0           0            11859
# 820372  2023-05-25  Centro-Oeste        907556.0           0            11859
# 820373  2023-05-26  Centro-Oeste        907556.0           0            11859
#
#         obitosNovos
# ...

# %% [markdown]
# Conversão importante:

# %%
# convertendo a coluna Data para o formato data

df_total_ft['data'] = pd.to_datetime(df_total_ft['data'])
# Out:
# <ipython-input-23-8dc626879b60>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_total_ft['data'] = pd.to_datetime(df_total_ft['data'])

# %%
df_total_ft.head()
# Out:
#         data  regiao  casosAcumulado  casosNovos  obitosAcumulado  obitosNovos
# 0 2020-02-25  Brasil             0.0           0                0            0
# 1 2020-02-26  Brasil             1.0           1                0            0
# 2 2020-02-27  Brasil             1.0           0                0            0
# 3 2020-02-28  Brasil             1.0           0                0            0
# 4 2020-02-29  Brasil             2.0           1                0            0

# %% [markdown]
# ## EX14:
# Faça um filtro em `df_total_ft` pela Região = Brasil. Dica: chame esse filtro de `df_total_br`.

# %%
# filtro
df_total_br = df_total_ft[df_total_ft['regiao'] == 'Brasil']

# %%
display(df_total_br)
# Out:
#           data  regiao  casosAcumulado  casosNovos  obitosAcumulado  \
# 0   2020-02-25  Brasil             0.0           0                0
# 1   2020-02-26  Brasil             1.0           1                0
# 2   2020-02-27  Brasil             1.0           0                0
# 3   2020-02-28  Brasil             1.0           0                0
# 4   2020-02-29  Brasil             2.0           1                0
# ..         ...     ...             ...         ...              ...
# 141 2023-05-22  Brasil      37579028.0           0           702664
# 142 2023-05-23  Brasil      37579028.0           0           702664
# 143 2023-05-24  Brasil      37579028.0           0           702664
# 144 2023-05-25  Brasil      37579028.0           0           702664
# 145 2023-05-26  Brasil      37579028.0           0           702664
#
#      obitosNovos
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ..           ...
# 141            0
# ...

# %% [markdown]
# ## EX15:
# Obtenha, pelo método `.info()`, as informações do `df_total_br`.

# %%
df_total_br.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1187 entries, 0 to 145
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   data             1187 non-null   datetime64[ns]
#  1   regiao           1187 non-null   object
#  2   casosAcumulado   1187 non-null   float64
#  3   casosNovos       1187 non-null   int64
#  4   obitosAcumulado  1187 non-null   int64
#  5   obitosNovos      1187 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(1)
# memory usage: 64.9+ KB

# %% [markdown]
# ## EX16:
# Graficamente, represente graficamente as informações contidas no `df_total_br` em função do tempo.

# %%
# Análise casos acumulados
plt.figure(figsize=(10, 5))
plt.plot(df_total_br['data'], df_total_br['casosAcumulado'], label='Casos Acumulados')

# Personalizando o gráfico
plt.xlabel('Data')
plt.ylabel('Quantidade')
plt.title('Gráfico de Linhas')
plt.legend(loc='upper left')

# %%
# Análise casos novos
plt.figure(figsize=(10, 5))
plt.plot(df_total_br['data'], df_total_br['casosNovos'], label='Casos Novos')

# Personalizando o gráfico
plt.xlabel('Data')
plt.ylabel('Quantidade')
plt.title('Gráfico de Linhas')
plt.legend(loc='upper left')

# %%
# Análise óbitos acumulados
plt.figure(figsize=(10, 5))
plt.plot(df_total_br['data'], df_total_br['obitosAcumulado'], label='Óbitos Acumulados')

# Personalizando o gráfico
plt.xlabel('Data')
plt.ylabel('Quantidade')
plt.title('Gráfico de Linhas')
plt.legend(loc='upper left')

# %%
# Análise óbitos acumulados
plt.figure(figsize=(10, 5))
plt.plot(df_total_br['data'], df_total_br['obitosNovos'], label='Óbitos Novos')

# Personalizando o gráfico
plt.xlabel('Data')
plt.ylabel('Quantidade')
plt.title('Gráfico de Linhas')
plt.legend(loc='upper left')

# %%
# Exemplo com o Seaborn

# Seaborn vem com estilos predefinidos que melhoram a aparência dos gráficos
sns.set_theme()

# Criar figura e eixos
fig, ax1 = plt.subplots(figsize=(18, 6))

# Plotar a primeira coluna com estilo do seaborn
sns.lineplot(data=df_total_br, x=df_total_br.index, y='casosAcumulado', color='blue', ax=ax1)
ax1.set_xlabel('Data')
ax1.set_ylabel('Casos Acumulados', color='blue')

# Adicionar grade ao gráfico
ax1.grid(True)

# Criar o segundo eixo y
ax2 = ax1.twinx()

# Plotar a segunda coluna com estilo do seaborn
sns.lineplot(data=df_total_br, x=df_total_br.index, y='obitosAcumulado', color='red', ax=ax2)
ax2.set_ylabel('Óbitos Acumulados', color='red')

# Definir título
plt.title('Gráfico Óbitos e Casos Acumulados')

# Formatar data no eixo x
ax1.xaxis.set_major_locator(mdates.MonthLocator())
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))

# Selecionar cada segunda marca
xticks = ax1.get_xticks()
ax1.set_xticks(xticks[::2]) # escolhe cada segunda marca

# Rotacionar rótulos do eixo x
plt.setp(ax1.get_xticklabels(), rotation=45)

# Ajustar o espaçamento entre subplots
fig.tight_layout()

# Exibir o gráfico
plt.show()

# %% [markdown]
# ## EX17:
# Crie um gráfico com dois eixos `y` (ou seja, lado esquerdo e lado direito do gráfico com informações) relacionando casos novos com óbitos novos.

# %%
sns.set_theme()

fig, ax1 = plt.subplots(figsize=(18, 6))

data = df_total_br[['data', 'casosNovos', 'obitosNovos']]

sns.lineplot(data=data, x='data', y='casosNovos', color='blue', ax=ax1)
ax1.set_xlabel('Data')
ax1.set_ylabel('Casos Novos', color='blue')

ax1.grid(True)

ax2 = ax1.twinx()

sns.lineplot(data=data, x='data', y='obitosNovos', color='red', ax=ax2)
ax2.set_ylabel('Óbitos Novos', color='red')

plt.title('Gráfico Óbitos e Casos Novos')

ax1.xaxis.set_major_locator(mdates.MonthLocator())
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))

xticks = ax1.get_xticks()
ax1.set_xticks(xticks[::2]) # escolhe cada segunda marca

plt.setp(ax1.get_xticklabels(), rotation=45)

fig.tight_layout()
plt.show()

# %% [markdown]
# ## EX18:
# Quais conclusões você consegue extrair desta análise?

# %% [markdown]
# É possível analisar que houve um crescimento de óbitos novos até o pico alcançado entre março e maio de 2021, que a partir dessa data foi diminuindo gradativamente até 2022, que seguiu com o mesmo padrão, com somente uma pequena alta entre janeiro e março de 2022. Já os casos novos se mantiveram numa frequência parecida, até surgirem curtos picos em setembro de 2021 e entre janeiro e março de 2022, que após isso foi diminuindo gradativamente.

# %% [markdown]
# ## EX19:
# Com o método `.info()`, analise o `df_vacinados`.

# %%
df_vacinados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 861 entries, 0 to 860
# Data columns (total 3 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Data da Vacina                      861 non-null    datetime64[ns]
#  1   Total de Doses Aplicadas            861 non-null    int64
#  2   Total de Doses Aplicadas Acumulado  861 non-null    int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 20.3 KB

# %% [markdown]
# Conversão importante para se trabalhar com datas:

# %%
# A função to_datetime() do pandas é usada para converter a coluna 'Data da Vacina' do DataFrame df_vacinados para o tipo datetime.
# Isso é útil para manipular corretamente as datas posteriormente.
df_vacinados['Data da Vacina'] = pd.to_datetime(df_vacinados['Data da Vacina'])

# Em seguida, a função set_index() é usada para definir a coluna 'Data da Vacina' como o índice do DataFrame.
# Um índice funciona como uma etiqueta para as linhas, o que permite selecionar e referenciar as linhas de maneira mais fácil.
# O argumento inplace=True significa que essa operação modifica o DataFrame df_vacinados diretamente, em vez de criar um novo DataFrame.
df_vacinados.set_index('Data da Vacina', inplace=True)

# %%
df_vacinados.head(-5)
# Out:
#                 Total de Doses Aplicadas  Total de Doses Aplicadas Acumulado
# Data da Vacina
# 2021-01-17                         43066                               43066
# 2021-01-18                          3198                               46264
# 2021-01-19                         62679                              108943
# 2021-01-20                        350217                              459160
# 2021-01-21                        394482                              853642
# ...                                  ...                                 ...
# 2023-05-18                         43357                           513883618
# 2023-05-19                         45244                           513928862
# 2023-05-20                         35613                           513964475
# 2023-05-21                           713                           513965188
# 2023-05-22                         35916                           514001104
#
# [856 rows x 2 columns]

# %% [markdown]
# ## EX20:
#
# Construa um  gráfico contendo os Casos Acumulados x Total Doses Aplicadas Acumuladas.

# %%
sns.set_theme()

data1 = df_total_br[['data', 'casosAcumulado']]
data2 = df_vacinados[['Total de Doses Aplicadas Acumulado']]

fig, ax1 = plt.subplots(figsize=(18, 6))

sns.lineplot(data=data1, x='data', y='casosAcumulado', color='blue', ax=ax1)
ax1.set_xlabel('Data')
ax1.set_ylabel('Casos Acumulados', color='blue')

ax1.grid(True)

ax2 = ax1.twinx()

sns.lineplot(data=data2, x='Data da Vacina', y='Total de Doses Aplicadas Acumulado', color='red', ax=ax2)
ax2.set_ylabel('Total de Doses Aplicadas Acumuladas', color='red')

plt.title('Gráfico de Casos Acumulados e Total de Doses Aplicadas Acumulado')

ax1.xaxis.set_major_locator(mdates.MonthLocator())
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))

xticks = ax1.get_xticks()
ax1.set_xticks(xticks[::2]) # escolhe cada segunda marca

plt.setp(ax1.get_xticklabels(), rotation=45)

fig.tight_layout()
plt.show()

# %% [markdown]
# ## EX21:
#
# Construa um  gráfico contendo os Óbitos Acumulados x Total Doses Aplicadas Acumuladas.

# %%
sns.set_theme()

data1 = df_total_br[['data', 'obitosAcumulado']]
data2 = df_vacinados[['Total de Doses Aplicadas Acumulado']]

fig, ax1 = plt.subplots(figsize=(18, 6))

sns.lineplot(data=data1, x='data', y='obitosAcumulado', color='blue', ax=ax1)
ax1.set_xlabel('Data')
ax1.set_ylabel('Óbitos Acumulados', color='blue')

ax1.grid(True)

ax2 = ax1.twinx()

sns.lineplot(data=data2, x='Data da Vacina', y='Total de Doses Aplicadas Acumulado', color='red', ax=ax2)
ax2.set_ylabel('Total de Doses Aplicadas Acumuladas', color='red')

plt.title('Gráfico de Óbitos Acumulados e Total de Doses Aplicadas Acumulado')

ax1.xaxis.set_major_locator(mdates.MonthLocator())
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))

xticks = ax1.get_xticks()
ax1.set_xticks(xticks[::2]) # escolhe cada segunda marca

plt.setp(ax1.get_xticklabels(), rotation=45)

fig.tight_layout()
plt.show()

# %% [markdown]
# ## EX22:
#
# Construa um  gráfico contendo os Óbitos diários x Doses Aplicadas Acumuladas.

# %%
sns.set_theme()

data1 = df_total_br[['data', 'obitosNovos']]
data2 = df_vacinados[['Total de Doses Aplicadas Acumulado']]

fig, ax1 = plt.subplots(figsize=(18, 6))

sns.lineplot(data=data1, x='data', y='obitosNovos', color='blue', ax=ax1)
ax1.set_xlabel('Data')
ax1.set_ylabel('Óbitos Novos', color='blue')

ax1.grid(True)

ax2 = ax1.twinx()

sns.lineplot(data=data2, x='Data da Vacina', y='Total de Doses Aplicadas Acumulado', color='red', ax=ax2)
ax2.set_ylabel('Total de Doses Aplicadas Acumuladas', color='red')

plt.title('Gráfico de Óbitos Novos e Total de Doses Aplicadas Acumulado')

ax1.xaxis.set_major_locator(mdates.MonthLocator())
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))

xticks = ax1.get_xticks()
ax1.set_xticks(xticks[::2]) # escolhe cada segunda marca

plt.setp(ax1.get_xticklabels(), rotation=45)

fig.tight_layout()
plt.show()

# %% [markdown]
# **Principais variantes**
#
# <img src="https://agencia.fiocruz.br/sites/agencia.fiocruz.br/files/u35/fhcgkkjxoaayirp.jpg" width=1000>

# %% [markdown]
# ## EX23:
#
# Com as informações contidas no gráfico do EX22 e com a informação sobre as variantes, quais conclusões você extrai desta análise? Justifique.

# %% [markdown]
# A vacinação contribuiu para uma queda significante no número de novos óbitos. Pois é possível de analisar no gráfico que as variantes BA.1, BA.5 e BE.9 houveram poucos óbitos proporcionalmente ao número de casos confirmados, e isso ocorreu devido ao aumento do número de pessoa vacinadas. É possível comprovar também analisando a variante P.1, pois não havia vacinação, e houve mais óbitos do que a variante BA.1, que possuiu mais casos confirmados.

# %% [markdown]
# # Links importantes:
#
# * [Mapa da vacinação](https://especiais.g1.globo.com/bemestar/vacina/2021/mapa-brasil-vacina-covid/)
# * [Ministério da Saúde - Vacinômetro](https://infoms.saude.gov.br/extensions/SEIDIGI_DEMAS_Vacina_C19/SEIDIGI_DEMAS_Vacina_C19.html#)
# * [Linha do tempo do Coronavírus no Brasil](https://www.sanarmed.com/linha-do-tempo-do-coronavirus-no-brasil)
# * [Principais variantes do SARS-CoV-2 notificadas no Brasil ](https://www.rbac.org.br/artigos/principais-variantes-do-sars-cov-2-notificadas-no-brasil/)
# * [Rede Genômica Fiocruz identifica surgimento de nova variante da Ômicron](https://portal.fiocruz.br/noticia/rede-genomica-fiocruz-identifica-surgimento-de-nova-variante-da-omicron)

# %% [markdown]
# # **EXTRA**: Extraçao de dados usando uma API
#
# https://opendatasus.saude.gov.br/group/dados-do-coranavirus

# %%
import requests

# O URL para a API
url = 'https://imunizacao-es.saude.gov.br/_search'

# Faz a requisição para a API
response = requests.get(url, auth=('imunizacao_public', 'qlto5t&7r_@+#Tlstigi'))

# Verifica se a requisição foi bem sucedida
if response.status_code == 200:
    # Converte a resposta em JSON para um dicionário Python
    data = response.json()

    # Supondo que os dados que você quer estão na chave 'hits' do dicionário,
    # e dentro disso, cada 'hit' tem um campo '_source' que contém os dados relevantes
    hits = data.get('hits', {}).get('hits', [])

    # Agora, você pode criar uma lista de todos os campos '_source' e transformá-los em um DataFrame
    source_data = [hit.get('_source', {}) for hit in hits]

    df = pd.DataFrame(source_data)
    print(df)
else:
    print('Erro na requisição:', response.status_code)
# Out:
#   paciente_nacionalidade_enumNacionalidade vacina_categoria_codigo  \
# 0                                        B                     114
# 1                                        B                       2
# 2                                        B                       2
# 3                                        B                    None
# 4                                        B                       2
# 5                                        B                       2
# 6                                        B                       2
# 7                                        E                       2
# 8                                        B                       2
# 9                                        B                       2
#
#   paciente_endereco_nmMunicipio  \
# 0              FEIRA DE SANTANA
# 1              FEIRA DE SANTANA
# 2              FEIRA DE SANTANA
# 3              FEIRA DE SANTANA
# 4                         MUQUI
# ...

# %%
df.head()
# Out:
#   paciente_nacionalidade_enumNacionalidade vacina_categoria_codigo  \
# 0                                        B                     114
# 1                                        B                       2
# 2                                        B                       2
# 3                                        B                    None
# 4                                        B                       2
#
#   paciente_endereco_nmMunicipio  \
# 0              FEIRA DE SANTANA
# 1              FEIRA DE SANTANA
# 2              FEIRA DE SANTANA
# 3              FEIRA DE SANTANA
# 4                         MUQUI
#
#                                          paciente_id paciente_dataNascimento  \
# 0  ea6234c63332f50ee3b735b93bfa5f60b591de935ed26c...              2001-03-07
# 1  48c394018ea571c4ae9c3fddf43ce09c2299f6c65eb65f...              1966-08-10
# 2  32010422270eb73f2caf14475e33ccfd759eeb81142973...              1982-03-12
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 42 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   paciente_nacionalidade_enumNacionalidade  10 non-null     object
#  1   vacina_categoria_codigo                   9 non-null      object
#  2   paciente_endereco_nmMunicipio             10 non-null     object
#  3   paciente_id                               10 non-null     object
#  4   paciente_dataNascimento                   10 non-null     object
#  5   ds_condicao_maternal                      0 non-null      object
#  6   estabelecimento_razaoSocial               10 non-null     object
#  7   estabelecimento_valor                     10 non-null     object
#  8   estabelecimento_uf                        10 non-null     object
#  9   paciente_endereco_coIbgeMunicipio         10 non-null     object
# ...

# %%
# O URL para a API
url = 'https://imunizacao-es.saude.gov.br/_search'

# O tamanho da página (número de hits por página)
page_size = 10000

# A página inicial
page = 0

# Uma lista para armazenar todos os dados
data = []

# Loop até que não haja mais dados
while True:
    # A consulta para a API
    query = {
        "size": page_size,
        "from": page * page_size,
        "_source": ["vacina_dataAplicacao", "vacina_descricao_dose"],
        "query": {
            "match_all": {}
        }
    }

    # Faz a requisição para a API
    response = requests.get(url, json=query, auth=('imunizacao_public', 'qlto5t&7r_@+#Tlstigi'))

    # Verifica se a requisição foi bem sucedida
    if response.status_code != 200:
        print('Erro na requisição:', response.status_code)
        break

    # Converte a resposta em JSON para um dicionário Python
    page_data = response.json()

    # Extrai os hits da resposta
    hits = page_data.get('hits', {}).get('hits', [])

    # Se não houver mais hits, sai do loop
    if not hits:
        break

    # Extrai os dados relevantes dos hits e adiciona à lista de dados
    data.extend(hit.get('_source', {}) for hit in hits)

    # Incrementa a página para a próxima iteração
    page += 1

# Converte os dados em um DataFrame
df_vacinacao = pd.DataFrame(data)

print(df_vacinacao)
# Out:
# Erro na requisição: 400
#           vacina_dataAplicacao vacina_descricao_dose
# 0     2023-08-26T00:00:00.000Z               1ª Dose
# 1     2023-10-03T00:00:00.000Z            1º Reforço
# 2     2023-09-29T00:00:00.000Z            1º Reforço
# 3     2023-10-04T00:00:00.000Z            1º Reforço
# 4     2023-10-02T00:00:00.000Z               1ª Dose
# ...                        ...                   ...
# 9995  2023-09-25T00:00:00.000Z               1ª Dose
# 9996  2023-03-28T00:00:00.000Z            2º Reforço
# 9997  2023-09-18T00:00:00.000Z               3ª Dose
# 9998  2023-09-26T00:00:00.000Z            1º Reforço
# 9999  2023-01-25T00:00:00.000Z            1º Reforço
#
# [10000 rows x 2 columns]

# %%
df_vacinacao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   vacina_dataAplicacao   10000 non-null  object
#  1   vacina_descricao_dose  10000 non-null  object
# dtypes: object(2)
# memory usage: 156.4+ KB

# %%
df_vacinacao.head(-5)
# Out:
#           vacina_dataAplicacao vacina_descricao_dose
# 0     2023-08-26T00:00:00.000Z               1ª Dose
# 1     2023-10-03T00:00:00.000Z            1º Reforço
# 2     2023-09-29T00:00:00.000Z            1º Reforço
# 3     2023-10-04T00:00:00.000Z            1º Reforço
# 4     2023-10-02T00:00:00.000Z               1ª Dose
# ...                        ...                   ...
# 9990  2022-02-25T00:00:00.000Z               2ª Dose
# 9991  2023-09-26T00:00:00.000Z               2ª Dose
# 9992  2023-09-27T00:00:00.000Z               3ª Dose
# 9993  2023-09-27T00:00:00.000Z               2ª Dose
# 9994  2023-09-27T00:00:00.000Z               Reforço
#
# [9995 rows x 2 columns]

# %%
# convertendo a coluna Data para o formato data

df_vacinacao['vacina_dataAplicacao'] = pd.to_datetime(df_vacinacao['vacina_dataAplicacao']).dt.strftime('%Y-%m-%d')
df_vacinacao.set_index('vacina_dataAplicacao', inplace=True)

# %%
df_vacinacao.head(-5)
# Out:
#                      vacina_descricao_dose
# vacina_dataAplicacao
# 2023-08-26                         1ª Dose
# 2023-10-03                      1º Reforço
# 2023-09-29                      1º Reforço
# 2023-10-04                      1º Reforço
# 2023-10-02                         1ª Dose
# ...                                    ...
# 2022-02-25                         2ª Dose
# 2023-09-26                         2ª Dose
# 2023-09-27                         3ª Dose
# 2023-09-27                         2ª Dose
# 2023-09-27                         Reforço
#
# [9995 rows x 1 columns]

# %%
valores_unicos = df_vacinacao['vacina_descricao_dose'].unique()
print(valores_unicos)
# Out:
# ['1ª Dose' '1º Reforço' '1ª Dose Revacinação' '2ª Dose' '3ª Dose'
#  'Reforço' 'Revacinação' '2º Reforço' '4ª Dose Revacinação' '5ª Dose'
#  '4º Reforço' '2ª Dose Revacinação' 'Dose Adicional' '3º Reforço' 'Dose'
#  '3ª Dose Revacinação' '5ª Dose Revacinação' '4ª Dose' 'Única']

# %%
df_vacinacao = df_vacinacao.sort_values('vacina_dataAplicacao')
df_vacinacao.head(-5)
# Out:
#                      vacina_descricao_dose
# vacina_dataAplicacao
# 2021-01-31                         1ª Dose
# 2021-02-02                         1ª Dose
# 2021-02-05                         2ª Dose
# 2021-02-23                         2ª Dose
# 2021-03-13                         1ª Dose
# ...                                    ...
# 2023-10-04                         2ª Dose
# 2023-10-04                         2ª Dose
# 2023-10-04                         2ª Dose
# 2023-10-04                         2ª Dose
# 2023-10-04                         3ª Dose
#
# [9995 rows x 1 columns]

# %% [markdown]
# # Web Scraping
#
# Web scraping é uma técnica de extração de dados da web, que consiste em coletar informações de sites de forma automatizada. O termo "scraping" vem do inglês e significa "raspar" ou "coletar raspando".
#
# O processo de web scraping envolve o acesso a uma página da web, a análise da estrutura HTML dessa página e a extração dos dados desejados. Isso é feito utilizando bibliotecas ou frameworks específicos em uma linguagem de programação, como Python.
#
# Os dados podem ser extraídos de várias maneiras, incluindo a análise do HTML da página para identificar elementos específicos, como tags, classes ou IDs, e extrair o conteúdo dentro desses elementos. Além disso, é possível seguir links para outras páginas e repetir o processo de extração em várias páginas relacionadas.
#
# Existem diversas ferramentas e bibliotecas populares em Python para facilitar o web scraping, como BeautifulSoup, Selenium, Scrapy e Requests. Essas bibliotecas fornecem funcionalidades para fazer requisições HTTP, analisar o HTML, extrair dados estruturados e até mesmo interagir com páginas da web que dependem de JavaScript.
#
# No entanto, ao realizar web scraping, é importante conhecer e respeitar as leis e políticas de uso dos sites, bem como evitar sobrecarregar os servidores com um grande número de requisições em curtos intervalos de tempo.
#
# Exemplos:
#
# * https://github.com/renatapink/DSdegree/blob/master/Modulo1/Aula19/Webscraping%20-%20Aula1%20-%20ADVFN.ipynb

# %% [markdown]
# # Referências Bibliográficas
#
# * BRUCE, P., BRUNCE, A., Estatística Prática para Cientistas de Dados, Alta Books, São Paulo, 2019;
